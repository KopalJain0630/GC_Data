# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv('/content/1.csv', sep=',', header=None)
df_2 = pd.read_csv('/content/2.csv', sep=',', header=None)
df_3 = pd.read_csv('/content/3.csv', sep=',', header=None)
df_4 = pd.read_csv('/content/4.csv', sep=',', header=None)

# %%
df_1
# Out:
#             0        1        2        3        4        5        6        7   \
# 0      index00  index01  index02  index03  index04  index05  index06  index07
# 1            0      1.0   0.4337   0.7431    0.939   0.7541   0.9035   0.7943
# 2            0      2.0   0.7859   0.1925   0.9024   0.8108   0.2016   0.9649
# 3            0      3.0   0.0512   0.9633   0.1423   0.8404   0.6654   0.4348
# 4            0      4.0   0.0413   0.1588   0.1675   0.0971   0.2918    0.197
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 11518     5234      2.0   0.0001   0.5861   0.9558   0.0581    0.346   0.8378
# 11519     5234      3.0   0.7255   0.2268   0.7441   0.8172   0.4259   0.3025
# 11520     5234      4.0   0.4054   0.3511   0.3857   0.8696   0.9721   0.8799
# 11521     5234      5.0   0.7439   0.9808   0.0385   0.5972   0.0798   0.4027
# 11522     5234      6.0   0.5753    0.493   0.0397   0.9478    0.079   0.4091
#
# ...

# %%
df_1.to_csv(r'norisk.csv')
df_2.to_csv(r'lowrisk.csv')
df_3.to_csv(r'mediumrisk.csv')
df_4.to_csv(r'catastrosphicrisk.csv')

# %%
dff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eef74c635d9a> in <module>
# ----> 1 dff
#
# NameError: name 'dff' is not defined

# %%
df1 = df_1.tail(-1)
df1=df1.astype(float)

# %%
import sympy

# %%
from sympy import fft

# %%
from scipy.fftpack import fft

# %%
transform = fft(seq)
print (transform)
# Out:
# [48.6593    -0.j          0.51704554-0.89826362j -1.12298419-0.09326912j
#  -2.42031513-1.4405069j   0.64762395+2.04421637j  2.80963985-1.00627205j
#  -3.0441452 -1.78498392j -4.78600004-2.78031306j  3.21389078-1.32806995j
#  -0.17963626+0.32003901j  1.37583002+0.58277929j -0.18079595-1.86612421j
#  -0.4528276 +0.5029695j  -3.68421042+2.27802292j  1.86849059+1.09037556j
#  -1.07846148+0.34174989j  3.9488779 +2.25505184j -0.6769329 -1.03567957j
#  -0.47956567+3.77422877j  0.69269469+2.64666885j -1.84694975-1.46408115j
#  -2.66883661-2.70870929j  0.84924608-0.76084496j -2.76131692+0.35141131j
#   0.71267708-0.1413008j  -4.5275    +3.3836j      0.69380511+0.80802428j
#   1.35030723+3.97861454j -1.46411105-0.16720391j -2.19186805-0.57781406j
#  -1.70413002+4.02507723j -1.403879  -1.14542824j  1.09427271+3.00959196j
#  -2.14725047-4.59742825j -0.77297979-0.55435925j  0.3664992 -1.84918554j
#  -3.70484348-0.8778844j   1.49046853-0.41470905j -0.36779411+2.24847424j
# ...

# %%
seq=df1[2].to_numpy()

# %%
seq
# Out:
# array([0.4337, 0.7859, 0.0512, ..., 0.4054, 0.7439, 0.5753])

# %%
dff = df1[:100]

# %%
dff
# Out:
#        0     1       2       3       4       5       6       7       8   \
# 1     0.0   1.0  0.4337  0.7431  0.9390  0.7541  0.9035  0.7943  0.2622
# 2     0.0   2.0  0.7859  0.1925  0.9024  0.8108  0.2016  0.9649  0.2445
# 3     0.0   3.0  0.0512  0.9633  0.1423  0.8404  0.6654  0.4348  0.5751
# 4     0.0   4.0  0.0413  0.1588  0.1675  0.0971  0.2918  0.1970  0.0971
# 5     0.0   5.0  0.7042  0.4724  0.3901  0.2793  0.2522  0.1933  0.2694
# ..    ...   ...     ...     ...     ...     ...     ...     ...     ...
# 96   29.0   6.0  0.8412  0.0013  0.8260  0.7388  0.5160  0.5512  0.4826
# 97   29.0   7.0  0.3838  0.9553  0.1726  0.4871  0.7475  0.2402  0.2771
# 98   29.0   8.0  0.7761  0.5487  0.8691  0.6195  0.6798  0.4590  0.9521
# 99   29.0   9.0  0.2422  0.3335  0.4124  0.9400  0.1242  0.5094  0.7161
# 100  29.0  10.0  0.3026  0.8586  0.9327  0.4144  0.1386  0.8829  0.6566
#
#          9   ...      18      19      20      21      22      23      24  \
# ...

# %%
seq = dff[2].to_numpy()

# %%
import math
transform = fft(seq)
print (transform)
# Out:
# [47.7979000000000, -0.5114*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32)*cos(pi/16) - 0.41665*sqrt(2)*cos(pi/64)*cos(pi/32) - 0.5617 - 0.3874*sqrt(2)*cos(pi/64)*cos(pi/16) - 0.5654*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32) - 0.5724*sqrt(sqrt(2)/4 + 1/2)*cos(pi/32)*cos(pi/16) - 0.40185*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/16) - 0.39035*sqrt(2)*sqrt(sqrt(2)/4 + 1/2) - 0.39165*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/32)*cos(pi/16) - 0.3885*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/16) - 0.5106*sqrt(sqrt(2)/4 + 1/2)*cos(pi/16) - 0.67045*sqrt(2)*sqrt(1/2 - sqrt(2)/4)*cos(pi/32) - 0.3305*cos(pi/64)*cos(pi/32)*cos(pi/16) - 0.2322*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64) - 0.7938*sqrt(1/2 - sqrt(2)/4)*cos(pi/32)*cos(pi/16) - 0.6552*sqrt(1/2 - sqrt(2)/4)*cos(pi/64)*cos(pi/16) - 0.1748*sqrt(2)*cos(pi/32)*cos(pi/16) - 0.1709*sqrt(2)*cos(pi/16) - 0.165*sqrt(2) - 0.16505*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32) - 0.7505*sqrt(2)*sin(pi/16) - 0.1393*sqrt(2)*cos(pi/32) - 0.1505
# ...

# %%
plt.plot(transform)
plt.xlabel("Sample")
plt.ylabel("Real Value of FFT")
plt.title("Low Risk Samples")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-1c5dab4b5b5e> in <module>
# ----> 1 plt.plot(transform)
#       2 plt.xlabel("Sample")
#       3 plt.ylabel("Real Value of FFT")
#       4 plt.title("Low Risk Samples")
#       5 plt.grid()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
# ...

# %%
transform

# %%
array = np.array(transform)

# %%
x=array.real
y=array.imag

# %%
plt.plot(x, y)
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title("Fast Fourier Transform of Low Risk Samples")
plt.show()

# %%
plt.plot(np.abs(array))
plt.xlabel("Sample")
plt.ylabel("Absolute Value of FFT")
plt.title("Low Risk Samples")
plt.grid()
plt.show()

# %%
plt.plot(np.angle(array))
plt.grid()
plt.xlabel("Sample")
plt.ylabel("Phase of FFT")
plt.title("Low Risk Samples")
plt.show()

# %%
ffts = pd.DataFrame()
ffts["SampleID"] = ''
ffts["Timepoint"] = ''

# %%
for i in range (2, 27):
  seq = dff[i].to_numpy()
  transform = fft(seq)
  ffts[f'Transform{i-1}']=transform

# %%
ffts
# Out:
#    SampleID Timepoint          Transform1          Transform2  \
# 0       NaN       NaN   47.79790-0.00000j   49.38020-0.00000j
# 1       NaN       NaN -1.191660-0.438285j  1.172402-1.945507j
# 2       NaN       NaN  1.114813-1.675404j  1.423301+2.536419j
# 3       NaN       NaN -0.626535+1.268743j  0.964910-0.438609j
# 4       NaN       NaN  1.305643-0.460710j -1.753976-2.928081j
# ..      ...       ...                 ...                 ...
# 95      NaN       NaN  3.176210+0.873757j  1.720736+1.431007j
# 96      NaN       NaN  1.305643+0.460710j -1.753976+2.928081j
# 97      NaN       NaN -0.626535-1.268743j  0.964910+0.438609j
# 98      NaN       NaN  1.114813+1.675404j  1.423301-2.536419j
# 99      NaN       NaN -1.191660+0.438285j  1.172402+1.945507j
#
#             Transform3          Transform4          Transform5  \
# 0    56.41750-0.00000j   54.60330-0.00000j   51.62820-0.00000j
# 1  -0.664078-1.264135j -0.756380+2.119494j -1.872997+0.159897j
# ...

# %%
correlation=ffts.corr()
#plotting heatmap
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':8}, cmap='Blues').

# %%
dff
# Out:
#        0     1       2       3       4       5       6       7       8   \
# 1     0.0   1.0  0.4337  0.7431  0.9390  0.7541  0.9035  0.7943  0.2622
# 2     0.0   2.0  0.7859  0.1925  0.9024  0.8108  0.2016  0.9649  0.2445
# 3     0.0   3.0  0.0512  0.9633  0.1423  0.8404  0.6654  0.4348  0.5751
# 4     0.0   4.0  0.0413  0.1588  0.1675  0.0971  0.2918  0.1970  0.0971
# 5     0.0   5.0  0.7042  0.4724  0.3901  0.2793  0.2522  0.1933  0.2694
# ..    ...   ...     ...     ...     ...     ...     ...     ...     ...
# 96   29.0   6.0  0.8412  0.0013  0.8260  0.7388  0.5160  0.5512  0.4826
# 97   29.0   7.0  0.3838  0.9553  0.1726  0.4871  0.7475  0.2402  0.2771
# 98   29.0   8.0  0.7761  0.5487  0.8691  0.6195  0.6798  0.4590  0.9521
# 99   29.0   9.0  0.2422  0.3335  0.4124  0.9400  0.1242  0.5094  0.7161
# 100  29.0  10.0  0.3026  0.8586  0.9327  0.4144  0.1386  0.8829  0.6566
#
#          9   ...      18      19      20      21      22      23      24  \
# ...

# %%
for i in range (2, 26):
  plt.scatter(x=ffts["Transform1"].values.real,y=ffts[f'Transform{i}'].values.real, c ="blue")
  plt.xlabel("FFT of Sensor 1")
  plt.ylabel(f'FFT of Sensor {i}')
  plt.title("Relation between FFTs")
  plt.show()

# %%
for i in range(1,100):
  ffts["SampleID"][i]=dff[0][i]
# Out:
# <ipython-input-50-027d244cc526>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ffts["SampleID"][i]=dff[0][i]

# %%
for i in range(1,100):
  ffts["Timepoint"][i]=dff[1][i]
# Out:
# <ipython-input-51-a2dc43c772b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ffts["Timepoint"][i]=dff[1][i]

# %%
ffts
# Out:
#    SampleID Timepoint          Transform1          Transform2  \
# 0       1.0       1.0   47.79790-0.00000j   49.38020-0.00000j
# 1       0.0       1.0 -1.191660-0.438285j  1.172402-1.945507j
# 2       0.0       2.0  1.114813-1.675404j  1.423301+2.536419j
# 3       0.0       3.0 -0.626535+1.268743j  0.964910-0.438609j
# 4       0.0       4.0  1.305643-0.460710j -1.753976-2.928081j
# ..      ...       ...                 ...                 ...
# 95     29.0       5.0  3.176210+0.873757j  1.720736+1.431007j
# 96     29.0       6.0  1.305643+0.460710j -1.753976+2.928081j
# 97     29.0       7.0 -0.626535-1.268743j  0.964910+0.438609j
# 98     29.0       8.0  1.114813+1.675404j  1.423301-2.536419j
# 99     29.0       9.0 -1.191660+0.438285j  1.172402+1.945507j
#
#             Transform3          Transform4          Transform5  \
# 0    56.41750-0.00000j   54.60330-0.00000j   51.62820-0.00000j
# 1  -0.664078-1.264135j -0.756380+2.119494j -1.872997+0.159897j
# ...

# %%
figure = plt.figure(figsize=(30, 30))
for sensor in range(25):
    sensor_name = "Transform"+str(sensor+1)
    plt.subplot(7, 4, sensor+1)
    plt.hist(ffts[sensor_name], bins=100)
    plt.title(f"{sensor_name} histogram")
    plt.xlabel("Real part")
    plt.ylabel("Frequency")
figure.tight_layout(h_pad=1.0, w_pad=0.5)
plt.suptitle('Sensor Histograms Before Outlier Removal', y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/numpy/lib/histograms.py:852: ComplexWarning: Casting complex values to real discards the imaginary part
#   indices = f_indices.astype(np.intp)
# /usr/local/lib/python3.9/dist-packages/matplotlib/transforms.py:775: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.asarray(points, float)

# %%
figure = plt.figure(figsize=(30,30))
for sensor in range(25):
    sensor_name = "Transform"+str(sensor+1)
    plt.subplot(7, 4, sensor+1)
    plt.hist(ffts[sensor_name], bins=100,
             range=(ffts[sensor_name].quantile(0.02),
                    ffts[sensor_name].quantile(0.98)))
    plt.title(f"{sensor_name} histogram")
figure.tight_layout(h_pad=1.0, w_pad=0.5)
plt.suptitle('Sensor Histograms After Outlier Removal', y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/numpy/lib/histograms.py:852: ComplexWarning: Casting complex values to real discards the imaginary part
#   indices = f_indices.astype(np.intp)
# /usr/local/lib/python3.9/dist-packages/matplotlib/transforms.py:775: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.asarray(points, float)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-105859025cd3> in <module>
#       3     sensor_name = "Transform"+str(sensor+1)
#       4     plt.subplot(7, 4, sensor+1)
# ----> 5     plt.hist(ffts[sensor_name], bins=100,
#       6              range=(ffts[sensor_name].quantile(0.02),
#       7                     ffts[sensor_name].quantile(0.98)))
#
# ...

# %%
transforms = []
for sensor in range(25):

    sensor_name = "Transform"+str(sensor+1)
    transforms.append(sensor_name)
for j in range (100):
  for transform in transforms:
      ffts.loc[j,transform] = ffts[transform].loc[i*11:(i+1)*11-1].mean()
  ffts[transforms] = ffts[transforms].astype(complex)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/nanops.py:441: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = values.astype("float64")
# /usr/local/lib/python3.9/dist-packages/pandas/core/nanops.py:441: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = values.astype("float64")
# /usr/local/lib/python3.9/dist-packages/pandas/core/nanops.py:441: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = values.astype("float64")
# /usr/local/lib/python3.9/dist-packages/pandas/core/nanops.py:441: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = values.astype("float64")
# /usr/local/lib/python3.9/dist-packages/pandas/core/nanops.py:441: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = values.astype("float64")
# ...

# %%
transforms
# Out:
# ['Transform1',
#  'Transform2',
#  'Transform3',
#  'Transform4',
#  'Transform5',
#  'Transform6',
#  'Transform7',
#  'Transform8',
#  'Transform9',
#  'Transform10',
#  'Transform11',
#  'Transform12',
#  'Transform13',
#  'Transform14',
#  'Transform15',
#  'Transform16',
#  'Transform17',
#  'Transform18',
#  'Transform19',
#  'Transform20',
#  'Transform21',
#  'Transform22',
#  'Transform23',
#  'Transform24',
#  'Transform25']

# %%
ffts["Transform_Avg"] = ffts[transforms].apply(np.mean, axis=1)

# %%
ffts
# Out:
#             Transform1          Transform2          Transform3  \
# 0    47.79790-0.00000j   49.38020-0.00000j   56.41750-0.00000j
# 1  -1.191660-0.438285j  1.172402-1.945507j -0.664078-1.264135j
# 2   1.114813-1.675404j  1.423301+2.536419j  0.774472-3.101954j
# 3  -0.626535+1.268743j  0.964910-0.438609j -0.409947-0.139660j
# 4   1.305643-0.460710j -1.753976-2.928081j  1.629479-0.368366j
# ..                 ...                 ...                 ...
# 95  3.176210+0.873757j  1.720736+1.431007j  0.322505+0.558133j
# 96  1.305643+0.460710j -1.753976+2.928081j  1.629479+0.368366j
# 97 -0.626535-1.268743j  0.964910+0.438609j -0.409947+0.139660j
# 98  1.114813+1.675404j  1.423301-2.536419j  0.774472+3.101954j
# 99 -1.191660+0.438285j  1.172402+1.945507j -0.664078+1.264135j
#
#             Transform4          Transform5          Transform6  \
# 0    54.60330-0.00000j   51.62820-0.00000j   50.56310-0.00000j
# 1  -0.756380+2.119494j -1.872997+0.159897j  1.671711-1.822536j
# ...

# %%
array = np.array(ffts['Transform_Avg'])

# %%
ffts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-13ad7e515105> in <module>
# ----> 1 ffts
#
# NameError: name 'ffts' is not defined

# %%
type(array[1].real)
# Out:
# numpy.float64

# %%
ffts['SampleID'] = ffts['SampleID'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-774ec3584ff6> in <module>
# ----> 1 ffts['SampleID'] = ffts['SampleID'].astype(float)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
plt.scatter(ffts['SampleID'], array.real)
plt.title("Scatter Plot of Sample IDs")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-121aefbd824d> in <module>
# ----> 1 plt.scatter(ffts['SampleID'], array.real)
#       2 plt.title("Scatter Plot of Sample IDs")
#       3 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2815         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2816         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2817     __ret = gca().scatter(
#    2818         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2819         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
ffts = ffts.astype(float)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/dtypes/cast.py:1181: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-dcf96f95d3c5> in <module>
# ----> 1 ffts = ffts.astype(float)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
# ...

# %%
plt.scatter(ffts['SampleID'], array.imag)
plt.title("Scatter Plot of Sample IDs - Imaginary Part")

plt.show()

# %%
plt.scatter(ffts['SampleID'], np.abs(array))

# %%
plt.scatter(ffts['SampleID'], np.angle(array))

# %%
ffts.plot(x='SampleID', y=['Transform1','Transform9'])
plt.ylabel("Real Part")
plt.title("FFT Values")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SampleID'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.boxplot(array.real)
plt.title("FFT of Sensor1 Values")
plt.show()

# %%
ax = sns.boxplot(data=ffts).set(
    xlabel='Sensors',
    ylabel='FFT Real Values',
    title="Low Risk Samples"
)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:872: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(self._values, dtype)

# %%
sns.countplot(x='SampleID', data=ffts)
# Out:
# <AxesSubplot:xlabel='SampleID', ylabel='count'>

# %%
plt.plot(ffts['Timepoint'],ffts['Transform1'])
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(ffts['Timepoint'],ffts['Transform10'])

# %%
sns.countplot(ffts['Transform_Avg'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'aTransform_Avg'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.countplot(ffts['Transform_Avg'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transform_Avg', ylabel='count'>

# %%
sns.distplot(ffts['Transform_Avg'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:857: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(self._values, dtype)
# <AxesSubplot:xlabel='Transform_Avg', ylabel='Density'>
